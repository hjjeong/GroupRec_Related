# %%
#Pytorch
import torch
import torch.nn as nn
import torch.autograd as autograd
from torch.autograd import Variable
import torch.optim as optim
import torch.nn.functional as F
#Python Libs
import numpy as np
from time import time
import datetime
import gc
#Implementations
from model.agree_ori import AGREE
from config_douban import Config
from dataset_Meetup import GDataset
from batch_test import *

# %%
def training(model, train_loader, epoch_id, config):
    # user trainning
    t1 = time()
    model.train()
    learning_rates = config.lr
    lr = learning_rates[0]

    # optimizer
    optimizer = optim.Adam(model.parameters(), lr=0.005)

    losses = []

    *_, last = train_loader

    for batch_id, (g, pi_ni) in enumerate(train_loader):
        # Data Load
        group_input = g
        pos_item_input = pi_ni[:, 0]
        neg_item_input = pi_ni[:, 1]

        optimizer.zero_grad()
        model.zero_grad()

        pos_prediction = model(group_input, pos_item_input)
        neg_prediction = model(group_input, neg_item_input)
        #print(pos_prediction[0], neg_prediction[0])

        # Loss

        loss = torch.mean((pos_prediction - neg_prediction -1) **2)
        
        # record loss history
        #print("batch_id: " + str(batch_id) + " loss: " + str(loss.item()))
        if not torch.isinf(loss.data) and not torch.isnan(loss.data):
            losses.append(float(loss.item()))
        # Backward
        loss.backward()
        optimizer.step()
        del group_input, pos_item_input, neg_item_input
    gc.collect()
    print('Iteration %d,\tloss: [%.4f], time: [%.1fs]' % (epoch_id, np.mean(np.array(losses)), time() - t1))

# %%
def evaluation(model, groups_to_test, Ks, trainRatings, num_items):
    model.eval()
    t2 = time()
    ret = test(model, groups_to_test, Ks, trainRatings, num_items) #See batch_test

    print('\t Evaluation done [%.1f s]' % (time() - t2))
    for i, k in enumerate(Ks):
        print('\t\t @%d: HR = %.4f, NDCG = %.4f, Rec = %.4f' % (k, ret['hit_ratio'][i], ret['ndcg'][i], ret['recall'][i]))
    return ret

# %%
config = Config()
# Out:
# douban 100 256 [0.0005, 1e-06, 5e-07]

# %%
dataset = GDataset(config.user_dataset, config.group_dataset, config.user_in_group_path, 1)
num_groups, num_users, num_items = dataset.num_groups, dataset.num_users, dataset.num_items
print("num_groups: "+str(num_groups)+" num_users: "+str(num_users)+" num_items: "+str(num_items))
gu_dict = dataset.gu_dict
# Out:
# num_groups: 92489 num_users: 63893 num_items: 15741

# %%
test_warm = dataset.load_rating_file_as_dict(config.group_dataset + ".test.rating_warm")
test_cold = dataset.load_rating_file_as_dict(config.group_dataset + ".test.rating_cold")
valid = dataset.load_rating_file_as_dict(config.group_dataset + ".valid.rating")

# %%
agree = AGREE(num_users, num_items, num_groups, config.embedding_size, gu_dict, config.drop_ratio).cuda()
best_checkpoint = -1.0
best_weights_path = None
for num_negatives in config.num_negatives:
    dataset.num_negatives = num_negatives
    print("AGREE: embedding size %d, run Iteration: %d, #neg: %d" %(config.embedding_size, config.epoch, num_negatives))
    # train the model
    now = datetime.datetime.now().strftime("%Y-%m-%d")

    for epoch in range(config.epoch):
        training(agree, dataset.get_group_dataloader(config.batch_size), epoch, config)
        

        # Evaluation
        if epoch % 3 == 0:
            agree.eval()
            with torch.no_grad():
                ret = evaluation(agree, valid, config.topK[:2], dataset.group_trainRatings, dataset.num_items)
                cur_checkpoint = ret['hit_ratio'][1]
                #ret = evaluation(agree, test_cold, config.topK[:2], dataset.group_trainRatings, dataset.num_items)
                #cur_checkpoint += ret['hit_ratio'][1]
                #cur_checkpoint = cur_checkpoint/2
                current_weights_path = 'weights/agree'+str(config.dataset)+"_"+str(config.embedding_size)+"_"+str(config.lr[0])+'_'+str(num_negatives)+'_'+str(epoch)
                torch.save(agree.state_dict(), current_weights_path)
                if best_checkpoint <= cur_checkpoint:
                    best_weights_path = current_weights_path
                    best_checkpoint = cur_checkpoint
# Out:
# AGREE: embedding size 32, run Iteration: 100, #neg: 4
# Iteration 0,	loss: [0.7666], time: [864.8s]
# 	 Evaluation done [3266.8 s]
# 		 @5: HR = 0.0042, NDCG = 0.0017, Rec = 0.0042
# 		 @10: HR = 0.0085, NDCG = 0.0031, Rec = 0.0085
# Iteration 1,	loss: [0.3846], time: [865.9s]
# Iteration 2,	loss: [0.1895], time: [867.0s]
# Iteration 3,	loss: [0.1311], time: [866.2s]
# 	 Evaluation done [3256.3 s]
# 		 @5: HR = 0.0021, NDCG = 0.0009, Rec = 0.0021
# 		 @10: HR = 0.0085, NDCG = 0.0029, Rec = 0.0085
# Iteration 4,	loss: [0.1058], time: [866.9s]
# Iteration 5,	loss: [0.0934], time: [866.2s]
# Iteration 6,	loss: [0.0860], time: [865.6s]
# 	 Evaluation done [3270.3 s]
# 		 @5: HR = 0.0085, NDCG = 0.0057, Rec = 0.0085
# 		 @10: HR = 0.0191, NDCG = 0.0091, Rec = 0.0191
# Iteration 7,	loss: [0.0820], time: [866.8s]
# Iteration 8,	loss: [0.0793], time: [866.3s]
# Iteration 9,	loss: [0.0777], time: [865.5s]
# 	 Evaluation done [3253.5 s]
# 		 @5: HR = 0.0127, NDCG = 0.0071, Rec = 0.0127
# 		 @10: HR = 0.0254, NDCG = 0.0111, Rec = 0.0254
# Iteration 10,	loss: [0.0762], time: [867.8s]
# Iteration 11,	loss: [0.0755], time: [865.6s]
# Iteration 12,	loss: [0.0748], time: [866.3s]
# 	 Evaluation done [3253.2 s]
# 		 @5: HR = 0.0127, NDCG = 0.0076, Rec = 0.0127
# 		 @10: HR = 0.0360, NDCG = 0.0151, Rec = 0.0360
# Iteration 13,	loss: [0.0746], time: [866.1s]
# Iteration 14,	loss: [0.0742], time: [866.5s]
# Iteration 15,	loss: [0.0737], time: [865.7s]
# 	 Evaluation done [3245.3 s]
# 		 @5: HR = 0.0212, NDCG = 0.0127, Rec = 0.0212
# 		 @10: HR = 0.0318, NDCG = 0.0161, Rec = 0.0318
# Iteration 16,	loss: [0.0736], time: [866.9s]
# Iteration 17,	loss: [0.0736], time: [865.9s]
# Iteration 18,	loss: [0.0731], time: [866.9s]
# 	 Evaluation done [3239.7 s]
# 		 @5: HR = 0.0275, NDCG = 0.0172, Rec = 0.0275
# 		 @10: HR = 0.0360, NDCG = 0.0200, Rec = 0.0360
# Iteration 19,	loss: [0.0730], time: [866.7s]
# Iteration 20,	loss: [0.0729], time: [866.5s]
# Iteration 21,	loss: [0.0728], time: [866.2s]
# 	 Evaluation done [3251.4 s]
# 		 @5: HR = 0.0191, NDCG = 0.0127, Rec = 0.0191
# 		 @10: HR = 0.0403, NDCG = 0.0197, Rec = 0.0403
# Iteration 22,	loss: [0.0727], time: [866.5s]
# Iteration 23,	loss: [0.0727], time: [866.9s]
# Iteration 24,	loss: [0.0726], time: [867.9s]
# 	 Evaluation done [3254.6 s]
# 		 @5: HR = 0.0191, NDCG = 0.0134, Rec = 0.0191
# 		 @10: HR = 0.0381, NDCG = 0.0195, Rec = 0.0381
# Iteration 25,	loss: [0.0725], time: [867.8s]
# Iteration 26,	loss: [0.0725], time: [867.7s]
# Iteration 27,	loss: [0.0724], time: [867.2s]
# 	 Evaluation done [3256.6 s]
# 		 @5: HR = 0.0212, NDCG = 0.0134, Rec = 0.0212
# 		 @10: HR = 0.0403, NDCG = 0.0194, Rec = 0.0403
# Iteration 28,	loss: [0.0724], time: [866.6s]
# Iteration 29,	loss: [0.0722], time: [858.3s]
# Iteration 30,	loss: [0.0722], time: [866.3s]
# 	 Evaluation done [3258.6 s]
# 		 @5: HR = 0.0275, NDCG = 0.0187, Rec = 0.0275
# 		 @10: HR = 0.0424, NDCG = 0.0234, Rec = 0.0424
# Iteration 31,	loss: [0.0720], time: [867.4s]
# Iteration 32,	loss: [0.0719], time: [867.9s]
# Iteration 33,	loss: [0.0718], time: [867.6s]
# 	 Evaluation done [3253.4 s]
# 		 @5: HR = 0.0297, NDCG = 0.0183, Rec = 0.0297
# 		 @10: HR = 0.0424, NDCG = 0.0223, Rec = 0.0424
# Iteration 34,	loss: [0.0718], time: [868.7s]
# Iteration 35,	loss: [0.0718], time: [867.9s]
# Iteration 36,	loss: [0.0718], time: [867.9s]
# 	 Evaluation done [3251.5 s]
# 		 @5: HR = 0.0275, NDCG = 0.0168, Rec = 0.0275
# 		 @10: HR = 0.0466, NDCG = 0.0226, Rec = 0.0466
# Iteration 37,	loss: [0.0717], time: [867.8s]
# Iteration 38,	loss: [0.0715], time: [868.6s]
# Iteration 39,	loss: [0.0716], time: [868.0s]
# 	 Evaluation done [3256.0 s]
# 		 @5: HR = 0.0212, NDCG = 0.0141, Rec = 0.0212
# 		 @10: HR = 0.0360, NDCG = 0.0188, Rec = 0.0360
# Iteration 40,	loss: [0.0716], time: [866.0s]
# Iteration 41,	loss: [0.0717], time: [866.6s]
# Iteration 42,	loss: [0.0714], time: [866.8s]
# 	 Evaluation done [3262.2 s]
# 		 @5: HR = 0.0318, NDCG = 0.0205, Rec = 0.0318
# 		 @10: HR = 0.0381, NDCG = 0.0223, Rec = 0.0381
# Iteration 43,	loss: [0.0715], time: [872.1s]
# Iteration 44,	loss: [0.0715], time: [866.8s]
# Iteration 45,	loss: [0.0714], time: [867.3s]
# 	 Evaluation done [3254.2 s]
# 		 @5: HR = 0.0254, NDCG = 0.0171, Rec = 0.0254
# 		 @10: HR = 0.0466, NDCG = 0.0239, Rec = 0.0466
# Iteration 46,	loss: [0.0714], time: [866.4s]
# Iteration 47,	loss: [0.0713], time: [867.1s]
# Iteration 48,	loss: [0.0714], time: [866.8s]
# 	 Evaluation done [3253.3 s]
# 		 @5: HR = 0.0233, NDCG = 0.0166, Rec = 0.0233
# 		 @10: HR = 0.0339, NDCG = 0.0198, Rec = 0.0339
# Iteration 49,	loss: [0.0713], time: [867.2s]
# Iteration 50,	loss: [0.0713], time: [866.5s]
# Iteration 51,	loss: [0.0713], time: [866.2s]
# 	 Evaluation done [3249.4 s]
# 		 @5: HR = 0.0318, NDCG = 0.0205, Rec = 0.0318
# 		 @10: HR = 0.0466, NDCG = 0.0251, Rec = 0.0466
# Iteration 52,	loss: [0.0713], time: [865.9s]
# Iteration 53,	loss: [0.0712], time: [866.2s]
# Iteration 54,	loss: [0.0710], time: [865.9s]
# 	 Evaluation done [3246.5 s]
# 		 @5: HR = 0.0275, NDCG = 0.0182, Rec = 0.0275
# 		 @10: HR = 0.0445, NDCG = 0.0233, Rec = 0.0445
# Iteration 55,	loss: [0.0711], time: [865.4s]
# Iteration 56,	loss: [0.0711], time: [866.6s]
# Iteration 57,	loss: [0.0712], time: [865.8s]
# 	 Evaluation done [3252.6 s]
# 		 @5: HR = 0.0233, NDCG = 0.0150, Rec = 0.0233
# 		 @10: HR = 0.0466, NDCG = 0.0223, Rec = 0.0466
# Iteration 58,	loss: [0.0711], time: [866.3s]
# Iteration 59,	loss: [0.0710], time: [866.3s]
# Iteration 60,	loss: [0.0709], time: [865.5s]
# 	 Evaluation done [3253.5 s]
# 		 @5: HR = 0.0297, NDCG = 0.0204, Rec = 0.0297
# 		 @10: HR = 0.0466, NDCG = 0.0256, Rec = 0.0466
# Iteration 61,	loss: [0.0708], time: [866.3s]
# Iteration 62,	loss: [0.0709], time: [866.9s]
# Iteration 63,	loss: [0.0707], time: [866.1s]
# 	 Evaluation done [3252.9 s]
# 		 @5: HR = 0.0275, NDCG = 0.0172, Rec = 0.0275
# 		 @10: HR = 0.0487, NDCG = 0.0238, Rec = 0.0487
# Iteration 64,	loss: [0.0708], time: [865.5s]
# Iteration 65,	loss: [0.0706], time: [866.5s]
# Iteration 66,	loss: [0.0709], time: [866.2s]
# 	 Evaluation done [3254.2 s]
# 		 @5: HR = 0.0275, NDCG = 0.0194, Rec = 0.0275
# 		 @10: HR = 0.0508, NDCG = 0.0268, Rec = 0.0508
# Iteration 67,	loss: [0.0708], time: [866.6s]
# Iteration 68,	loss: [0.0707], time: [868.2s]
# Iteration 69,	loss: [0.0706], time: [865.8s]
# 	 Evaluation done [3251.6 s]
# 		 @5: HR = 0.0297, NDCG = 0.0185, Rec = 0.0297
# 		 @10: HR = 0.0593, NDCG = 0.0277, Rec = 0.0593
# Iteration 70,	loss: [0.0705], time: [862.1s]
# Iteration 71,	loss: [0.0708], time: [862.7s]
# Iteration 72,	loss: [0.0705], time: [867.2s]
# 	 Evaluation done [3251.9 s]
# 		 @5: HR = 0.0381, NDCG = 0.0236, Rec = 0.0381
# 		 @10: HR = 0.0530, NDCG = 0.0282, Rec = 0.0530
# Iteration 73,	loss: [0.0705], time: [867.0s]
# Iteration 74,	loss: [0.0703], time: [866.2s]
# Iteration 75,	loss: [0.0704], time: [867.6s]
# 	 Evaluation done [3929.1 s]
# 		 @5: HR = 0.0318, NDCG = 0.0210, Rec = 0.0318
# 		 @10: HR = 0.0508, NDCG = 0.0270, Rec = 0.0508
# Iteration 76,	loss: [0.0706], time: [1205.0s]
# Iteration 77,	loss: [0.0704], time: [1165.0s]
# Iteration 78,	loss: [0.0703], time: [1086.3s]
# 	 Evaluation done [4573.0 s]
# 		 @5: HR = 0.0318, NDCG = 0.0200, Rec = 0.0318
# 		 @10: HR = 0.0572, NDCG = 0.0280, Rec = 0.0572
# Iteration 79,	loss: [0.0703], time: [1086.4s]
# Iteration 80,	loss: [0.0705], time: [1089.9s]
# Iteration 81,	loss: [0.0704], time: [1086.5s]
# 	 Evaluation done [4580.6 s]
# 		 @5: HR = 0.0275, NDCG = 0.0199, Rec = 0.0275
# 		 @10: HR = 0.0572, NDCG = 0.0294, Rec = 0.0572
# Iteration 82,	loss: [0.0705], time: [1090.0s]
# Iteration 83,	loss: [0.0705], time: [1088.0s]
# Iteration 84,	loss: [0.0704], time: [1090.5s]
# 	 Evaluation done [4583.9 s]
# 		 @5: HR = 0.0318, NDCG = 0.0224, Rec = 0.0318
# 		 @10: HR = 0.0508, NDCG = 0.0284, Rec = 0.0508
# Iteration 85,	loss: [0.0703], time: [1088.7s]
# Iteration 86,	loss: [0.0701], time: [1087.7s]
# Iteration 87,	loss: [0.0702], time: [1087.0s]
# 	 Evaluation done [4564.6 s]
# 		 @5: HR = 0.0339, NDCG = 0.0246, Rec = 0.0339
# 		 @10: HR = 0.0530, NDCG = 0.0308, Rec = 0.0530
# Iteration 88,	loss: [0.0702], time: [1088.7s]
# Iteration 89,	loss: [0.0702], time: [1088.8s]
# Iteration 90,	loss: [0.0700], time: [1091.1s]
# 	 Evaluation done [4581.0 s]
# 		 @5: HR = 0.0424, NDCG = 0.0257, Rec = 0.0424
# 		 @10: HR = 0.0593, NDCG = 0.0312, Rec = 0.0593
# Iteration 91,	loss: [0.0701], time: [1088.8s]
# Iteration 92,	loss: [0.0698], time: [1088.1s]
# Iteration 93,	loss: [0.0700], time: [1088.6s]
# 	 Evaluation done [4571.3 s]
# 		 @5: HR = 0.0360, NDCG = 0.0245, Rec = 0.0360
# 		 @10: HR = 0.0614, NDCG = 0.0325, Rec = 0.0614
# Iteration 94,	loss: [0.0700], time: [1087.2s]
# Iteration 95,	loss: [0.0699], time: [1089.9s]
# Iteration 96,	loss: [0.0699], time: [1089.0s]
# 	 Evaluation done [4594.6 s]
# 		 @5: HR = 0.0360, NDCG = 0.0247, Rec = 0.0360
# 		 @10: HR = 0.0593, NDCG = 0.0320, Rec = 0.0593
# Iteration 97,	loss: [0.0697], time: [1088.4s]
# Iteration 98,	loss: [0.0698], time: [1088.1s]
# Iteration 99,	loss: [0.0698], time: [1090.1s]
# 	 Evaluation done [4582.7 s]
# 		 @5: HR = 0.0339, NDCG = 0.0225, Rec = 0.0339
# 		 @10: HR = 0.0614, NDCG = 0.0313, Rec = 0.0614

# %%
print(best_weights_path)
agree = AGREE(num_users, num_items, num_groups, config.embedding_size, gu_dict, config.drop_ratio).cuda()
agree.load_state_dict(torch.load(best_weights_path))
ret = evaluation(agree, test_warm, config.topK[:2], dataset.group_trainRatings, dataset.num_items)
print('cold')
ret = evaluation(agree, test_cold, config.topK[:2], dataset.group_trainRatings, dataset.num_items)
# Out:
# weights/agreedouban_32_0.0005_4_99
# 	 Evaluation done [16589.7 s]
# 		 @5: HR = 0.0344, NDCG = 0.0226, Rec = 0.0344
# 		 @10: HR = 0.0610, NDCG = 0.0312, Rec = 0.0610
# cold
# 	 Evaluation done [86969.3 s]
# 		 @5: HR = 0.0112, NDCG = 0.0064, Rec = 0.0112
# 		 @10: HR = 0.0204, NDCG = 0.0094, Rec = 0.0204
