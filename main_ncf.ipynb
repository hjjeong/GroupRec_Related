# %%
#Pytorch
import torch
import torch.nn as nn
import torch.autograd as autograd
from torch.autograd import Variable
import torch.optim as optim
import torch.nn.functional as F
#Python Libs
import numpy as np
from time import time
import datetime
#Implementations
from model.agree_re import NCF
from config_douban import Config
from dataset_Meetup import GDataset
from batch_test import *

# %%
def training(model, train_loader, epoch_id, config):
    # user trainning
    t1 = time()
    model.train()
    learning_rates = config.lr
    lr = learning_rates[0]

    # optimizer
    optimizer = optim.Adam(model.parameters(), lr=0.001)

    losses = []

    *_, last = train_loader

    for batch_id, (g, pi_ni) in enumerate(train_loader):
        # Data Load
        group_input = g
        pos_item_input = pi_ni[:, 0]
        neg_item_input = pi_ni[:, 1]

        optimizer.zero_grad()
        model.zero_grad()

        pos_prediction = model(group_input, pos_item_input)
        neg_prediction = model(group_input, neg_item_input)
        #print(pos_prediction[0], neg_prediction[0])

        # Loss

        loss = torch.mean((pos_prediction - neg_prediction -1) **2)
        
        # record loss history
        #print("batch_id: " + str(batch_id) + " loss: " + str(loss.item()))
        if not torch.isinf(loss.data) and not torch.isnan(loss.data):
            losses.append(float(loss.item()))
        # Backward
        loss.backward()
        optimizer.step()

    print('Iteration %d,\tloss: [%.4f], time: [%.1fs]' % (epoch_id, np.mean(np.array(losses)), time() - t1))

# %%
def evaluation(model, groups_to_test, Ks, trainRatings, num_items):
    model.eval()
    t2 = time()
    ret = test(model, groups_to_test, Ks, trainRatings, num_items) #See batch_test

    print('\t Evaluation done [%.1f s]' % (time() - t2))
    for i, k in enumerate(Ks):
        print('\t\t @%d: HR = %.4f, NDCG = %.4f, Rec = %.4f' % (k, ret['hit_ratio'][i], ret['ndcg'][i], ret['recall'][i]))
    return ret

# %%
config = Config()
# Out:
# douban 100 256 [0.0005, 1e-06, 5e-07]

# %%
dataset = GDataset(config.user_dataset, config.group_dataset, config.user_in_group_path, 1)
num_groups, num_users, num_items = dataset.num_groups, dataset.num_users, dataset.num_items
print("num_groups: "+str(num_groups)+" num_users: "+str(num_users)+" num_items: "+str(num_items))
gu_dict = dataset.gu_dict
# Out:
# num_groups: 92489 num_users: 63893 num_items: 15741

# %%
test_warm = dataset.load_rating_file_as_dict(config.group_dataset + ".test.rating_warm")
test_cold = dataset.load_rating_file_as_dict(config.group_dataset + ".test.rating_cold")
valid = dataset.load_rating_file_as_dict(config.group_dataset + ".valid.rating")

# %%
agree = NCF(num_users, num_items, num_groups, config.embedding_size, gu_dict, 0.5)#.cuda()
best_checkpoint = -1.0
best_weights_path = None
for num_negatives in config.num_negatives:
    dataset.num_negatives = num_negatives
    print("NCF: embedding size %d, run Iteration: %d, #neg: %d" %(config.embedding_size, config.epoch, num_negatives))
    # train the model
    now = datetime.datetime.now().strftime("%Y-%m-%d")

    for epoch in range(config.epoch):
        training(agree, dataset.get_group_dataloader(config.batch_size), epoch, config)
        

        # Evaluation
        if epoch % 3 == 0:
            agree.eval()
            with torch.no_grad():
                #ret = evaluation(agree, test_warm, config.topK[:2], dataset.group_trainRatings, dataset.num_items)
                ret = evaluation(agree, valid, config.topK[:2], dataset.group_trainRatings, dataset.num_items)
                cur_checkpoint = ret['hit_ratio'][1]
                #ret = evaluation(agree, test_cold, config.topK[:2], dataset.group_trainRatings, dataset.num_items)
                #cur_checkpoint += ret['hit_ratio'][1]
                #cur_checkpoint = cur_checkpoint/2
                current_weights_path = 'weights/ncf'+str(config.dataset)+"_"+str(config.embedding_size)+"_"+str(config.lr[0])+'_'+str(num_negatives)+'_'+str(epoch)
                torch.save(agree.state_dict(), current_weights_path)
                if best_checkpoint <= cur_checkpoint:
                    best_weights_path = current_weights_path
                    best_checkpoint = cur_checkpoint
# Out:
# NCF: embedding size 32, run Iteration: 100, #neg: 4
# Iteration 0,	loss: [0.7709], time: [8.4s]
# 	 Evaluation done [39.4 s]
# 		 @5: HR = 0.0021, NDCG = 0.0008, Rec = 0.0021
# 		 @10: HR = 0.0021, NDCG = 0.0008, Rec = 0.0021
# Iteration 1,	loss: [0.4308], time: [7.5s]
# Iteration 2,	loss: [0.2598], time: [10.4s]
# Iteration 3,	loss: [0.1991], time: [10.4s]
# 	 Evaluation done [39.2 s]
# 		 @5: HR = 0.0042, NDCG = 0.0017, Rec = 0.0042
# 		 @10: HR = 0.0064, NDCG = 0.0024, Rec = 0.0064
# Iteration 4,	loss: [0.1717], time: [7.6s]
# Iteration 5,	loss: [0.1576], time: [10.3s]
# Iteration 6,	loss: [0.1498], time: [10.4s]
# 	 Evaluation done [31.2 s]
# 		 @5: HR = 0.0042, NDCG = 0.0017, Rec = 0.0042
# 		 @10: HR = 0.0106, NDCG = 0.0036, Rec = 0.0106
# Iteration 7,	loss: [0.1442], time: [7.6s]
# Iteration 8,	loss: [0.1415], time: [7.5s]
# Iteration 9,	loss: [0.1398], time: [10.5s]
# 	 Evaluation done [27.0 s]
# 		 @5: HR = 0.0042, NDCG = 0.0032, Rec = 0.0042
# 		 @10: HR = 0.0148, NDCG = 0.0066, Rec = 0.0148
# Iteration 10,	loss: [0.1388], time: [7.6s]
# Iteration 11,	loss: [0.1381], time: [7.5s]
# Iteration 12,	loss: [0.1374], time: [8.0s]
# 	 Evaluation done [23.6 s]
# 		 @5: HR = 0.0127, NDCG = 0.0098, Rec = 0.0127
# 		 @10: HR = 0.0212, NDCG = 0.0123, Rec = 0.0212
# Iteration 13,	loss: [0.1368], time: [9.5s]
# Iteration 14,	loss: [0.1367], time: [7.6s]
# Iteration 15,	loss: [0.1365], time: [7.5s]
# 	 Evaluation done [20.3 s]
# 		 @5: HR = 0.0127, NDCG = 0.0084, Rec = 0.0127
# 		 @10: HR = 0.0191, NDCG = 0.0104, Rec = 0.0191
# Iteration 16,	loss: [0.1362], time: [8.9s]
# Iteration 17,	loss: [0.1360], time: [8.9s]
# Iteration 18,	loss: [0.1359], time: [8.3s]
# 	 Evaluation done [18.7 s]
# 		 @5: HR = 0.0169, NDCG = 0.0103, Rec = 0.0169
# 		 @10: HR = 0.0254, NDCG = 0.0132, Rec = 0.0254
# Iteration 19,	loss: [0.1359], time: [7.6s]
# Iteration 20,	loss: [0.1356], time: [9.8s]
# Iteration 21,	loss: [0.1356], time: [10.1s]
# 	 Evaluation done [18.5 s]
# 		 @5: HR = 0.0148, NDCG = 0.0101, Rec = 0.0148
# 		 @10: HR = 0.0212, NDCG = 0.0120, Rec = 0.0212
# Iteration 22,	loss: [0.1356], time: [7.7s]
# Iteration 23,	loss: [0.1355], time: [7.5s]
# Iteration 24,	loss: [0.1354], time: [9.7s]
# 	 Evaluation done [19.2 s]
# 		 @5: HR = 0.0106, NDCG = 0.0069, Rec = 0.0106
# 		 @10: HR = 0.0233, NDCG = 0.0111, Rec = 0.0233
# Iteration 25,	loss: [0.1353], time: [7.6s]
# Iteration 26,	loss: [0.1353], time: [7.5s]
# Iteration 27,	loss: [0.1353], time: [7.7s]
# 	 Evaluation done [19.3 s]
# 		 @5: HR = 0.0085, NDCG = 0.0073, Rec = 0.0085
# 		 @10: HR = 0.0275, NDCG = 0.0133, Rec = 0.0275
# Iteration 28,	loss: [0.1353], time: [8.5s]
# Iteration 29,	loss: [0.1353], time: [7.6s]
# Iteration 30,	loss: [0.1352], time: [7.6s]
# 	 Evaluation done [18.4 s]
# 		 @5: HR = 0.0127, NDCG = 0.0077, Rec = 0.0127
# 		 @10: HR = 0.0191, NDCG = 0.0097, Rec = 0.0191
# Iteration 31,	loss: [0.1351], time: [9.1s]
# Iteration 32,	loss: [0.1351], time: [7.7s]
# Iteration 33,	loss: [0.1353], time: [7.6s]
# 	 Evaluation done [16.9 s]
# 		 @5: HR = 0.0127, NDCG = 0.0091, Rec = 0.0127
# 		 @10: HR = 0.0275, NDCG = 0.0140, Rec = 0.0275
# Iteration 34,	loss: [0.1351], time: [10.0s]
# Iteration 35,	loss: [0.1350], time: [11.2s]
# Iteration 36,	loss: [0.1350], time: [7.6s]
# 	 Evaluation done [17.1 s]
# 		 @5: HR = 0.0212, NDCG = 0.0132, Rec = 0.0212
# 		 @10: HR = 0.0254, NDCG = 0.0145, Rec = 0.0254
# Iteration 37,	loss: [0.1349], time: [9.2s]
# Iteration 38,	loss: [0.1347], time: [9.2s]
# Iteration 39,	loss: [0.1349], time: [9.1s]
# 	 Evaluation done [16.9 s]
# 		 @5: HR = 0.0233, NDCG = 0.0139, Rec = 0.0233
# 		 @10: HR = 0.0318, NDCG = 0.0167, Rec = 0.0318
# Iteration 40,	loss: [0.1347], time: [9.3s]
# Iteration 41,	loss: [0.1348], time: [9.3s]
# Iteration 42,	loss: [0.1347], time: [9.3s]
# 	 Evaluation done [17.0 s]
# 		 @5: HR = 0.0169, NDCG = 0.0106, Rec = 0.0169
# 		 @10: HR = 0.0254, NDCG = 0.0134, Rec = 0.0254
# Iteration 43,	loss: [0.1347], time: [7.6s]
# Iteration 44,	loss: [0.1346], time: [9.7s]
# Iteration 45,	loss: [0.1347], time: [9.6s]
# 	 Evaluation done [16.8 s]
# 		 @5: HR = 0.0148, NDCG = 0.0098, Rec = 0.0148
# 		 @10: HR = 0.0233, NDCG = 0.0124, Rec = 0.0233
# Iteration 46,	loss: [0.1346], time: [7.6s]
# Iteration 47,	loss: [0.1346], time: [8.9s]
# Iteration 48,	loss: [0.1347], time: [9.0s]
# 	 Evaluation done [17.4 s]
# 		 @5: HR = 0.0148, NDCG = 0.0088, Rec = 0.0148
# 		 @10: HR = 0.0297, NDCG = 0.0135, Rec = 0.0297
# Iteration 49,	loss: [0.1345], time: [7.6s]
# Iteration 50,	loss: [0.1346], time: [7.6s]
# Iteration 51,	loss: [0.1344], time: [9.7s]
# 	 Evaluation done [18.2 s]
# 		 @5: HR = 0.0148, NDCG = 0.0095, Rec = 0.0148
# 		 @10: HR = 0.0318, NDCG = 0.0150, Rec = 0.0318
# Iteration 52,	loss: [0.1344], time: [7.5s]
# Iteration 53,	loss: [0.1345], time: [7.6s]
# Iteration 54,	loss: [0.1344], time: [9.5s]
# 	 Evaluation done [18.4 s]
# 		 @5: HR = 0.0127, NDCG = 0.0096, Rec = 0.0127
# 		 @10: HR = 0.0297, NDCG = 0.0151, Rec = 0.0297
# Iteration 55,	loss: [0.1345], time: [7.7s]
# Iteration 56,	loss: [0.1345], time: [7.6s]
# Iteration 57,	loss: [0.1344], time: [7.8s]
# 	 Evaluation done [18.4 s]
# 		 @5: HR = 0.0169, NDCG = 0.0114, Rec = 0.0169
# 		 @10: HR = 0.0297, NDCG = 0.0155, Rec = 0.0297
# Iteration 58,	loss: [0.1343], time: [8.6s]
# Iteration 59,	loss: [0.1344], time: [7.6s]
# Iteration 60,	loss: [0.1343], time: [7.6s]
# 	 Evaluation done [17.6 s]
# 		 @5: HR = 0.0169, NDCG = 0.0110, Rec = 0.0169
# 		 @10: HR = 0.0318, NDCG = 0.0158, Rec = 0.0318
# Iteration 61,	loss: [0.1345], time: [10.5s]
# Iteration 62,	loss: [0.1343], time: [7.6s]
# Iteration 63,	loss: [0.1343], time: [7.6s]
# 	 Evaluation done [17.6 s]
# 		 @5: HR = 0.0127, NDCG = 0.0093, Rec = 0.0127
# 		 @10: HR = 0.0381, NDCG = 0.0177, Rec = 0.0381
# Iteration 64,	loss: [0.1342], time: [9.3s]
# Iteration 65,	loss: [0.1343], time: [7.6s]
# Iteration 66,	loss: [0.1343], time: [7.5s]
# 	 Evaluation done [17.7 s]
# 		 @5: HR = 0.0148, NDCG = 0.0107, Rec = 0.0148
# 		 @10: HR = 0.0318, NDCG = 0.0159, Rec = 0.0318
# Iteration 67,	loss: [0.1343], time: [8.9s]
# Iteration 68,	loss: [0.1342], time: [8.5s]
# Iteration 69,	loss: [0.1342], time: [7.6s]
# 	 Evaluation done [17.7 s]
# 		 @5: HR = 0.0106, NDCG = 0.0077, Rec = 0.0106
# 		 @10: HR = 0.0233, NDCG = 0.0117, Rec = 0.0233
# Iteration 70,	loss: [0.1341], time: [9.6s]
# Iteration 71,	loss: [0.1341], time: [9.6s]
# Iteration 72,	loss: [0.1342], time: [7.6s]
# 	 Evaluation done [16.9 s]
# 		 @5: HR = 0.0169, NDCG = 0.0101, Rec = 0.0169
# 		 @10: HR = 0.0275, NDCG = 0.0133, Rec = 0.0275
# Iteration 73,	loss: [0.1340], time: [10.4s]
# Iteration 74,	loss: [0.1340], time: [10.4s]
# Iteration 75,	loss: [0.1342], time: [7.6s]
# 	 Evaluation done [17.2 s]
# 		 @5: HR = 0.0212, NDCG = 0.0155, Rec = 0.0212
# 		 @10: HR = 0.0318, NDCG = 0.0189, Rec = 0.0318
# Iteration 76,	loss: [0.1341], time: [9.5s]
# Iteration 77,	loss: [0.1340], time: [9.4s]
# Iteration 78,	loss: [0.1340], time: [7.6s]
# 	 Evaluation done [17.2 s]
# 		 @5: HR = 0.0212, NDCG = 0.0146, Rec = 0.0212
# 		 @10: HR = 0.0318, NDCG = 0.0181, Rec = 0.0318
# Iteration 79,	loss: [0.1341], time: [8.9s]
# Iteration 80,	loss: [0.1340], time: [8.9s]
# Iteration 81,	loss: [0.1341], time: [7.8s]
# 	 Evaluation done [17.3 s]
# 		 @5: HR = 0.0169, NDCG = 0.0133, Rec = 0.0169
# 		 @10: HR = 0.0275, NDCG = 0.0165, Rec = 0.0275
# Iteration 82,	loss: [0.1340], time: [8.9s]
# Iteration 83,	loss: [0.1341], time: [8.8s]
# Iteration 84,	loss: [0.1340], time: [8.1s]
# 	 Evaluation done [17.1 s]
# 		 @5: HR = 0.0148, NDCG = 0.0105, Rec = 0.0148
# 		 @10: HR = 0.0254, NDCG = 0.0139, Rec = 0.0254
# Iteration 85,	loss: [0.1339], time: [8.9s]
# Iteration 86,	loss: [0.1341], time: [8.9s]
# Iteration 87,	loss: [0.1340], time: [8.7s]
# 	 Evaluation done [16.9 s]
# 		 @5: HR = 0.0212, NDCG = 0.0134, Rec = 0.0212
# 		 @10: HR = 0.0318, NDCG = 0.0167, Rec = 0.0318
# Iteration 88,	loss: [0.1341], time: [9.1s]
# Iteration 89,	loss: [0.1340], time: [9.1s]
# Iteration 90,	loss: [0.1339], time: [9.0s]
# 	 Evaluation done [16.5 s]
# 		 @5: HR = 0.0169, NDCG = 0.0113, Rec = 0.0169
# 		 @10: HR = 0.0318, NDCG = 0.0159, Rec = 0.0318
# Iteration 91,	loss: [0.1339], time: [10.0s]
# Iteration 92,	loss: [0.1339], time: [9.2s]
# Iteration 93,	loss: [0.1338], time: [9.1s]
# 	 Evaluation done [15.3 s]
# 		 @5: HR = 0.0169, NDCG = 0.0104, Rec = 0.0169
# 		 @10: HR = 0.0318, NDCG = 0.0153, Rec = 0.0318
# Iteration 94,	loss: [0.1339], time: [10.2s]
# Iteration 95,	loss: [0.1338], time: [10.3s]
# Iteration 96,	loss: [0.1340], time: [10.2s]
# 	 Evaluation done [15.4 s]
# 		 @5: HR = 0.0169, NDCG = 0.0108, Rec = 0.0169
# 		 @10: HR = 0.0381, NDCG = 0.0178, Rec = 0.0381
# Iteration 97,	loss: [0.1340], time: [10.3s]
# Iteration 98,	loss: [0.1338], time: [10.2s]
# Iteration 99,	loss: [0.1339], time: [10.2s]
# 	 Evaluation done [16.2 s]
# 		 @5: HR = 0.0169, NDCG = 0.0101, Rec = 0.0169
# 		 @10: HR = 0.0318, NDCG = 0.0147, Rec = 0.0318

# %%
print(best_weights_path)
agree = NCF(num_users, num_items, num_groups, config.embedding_size, gu_dict, config.drop_ratio)
agree.load_state_dict(torch.load(best_weights_path))
print('warm')
ret = evaluation(agree, test_warm, config.topK[:2], dataset.group_trainRatings, dataset.num_items)
print('cold')
ret = evaluation(agree, test_cold, config.topK[:2], dataset.group_trainRatings, dataset.num_items)
# Out:
# weights/ncfdouban_32_0.0005_4_96
# warm
# 	 Evaluation done [52.9 s]
# 		 @5: HR = 0.0266, NDCG = 0.0169, Rec = 0.0266
# 		 @10: HR = 0.0422, NDCG = 0.0220, Rec = 0.0422
# cold
# 	 Evaluation done [185.7 s]
# 		 @5: HR = 0.0003, NDCG = 0.0001, Rec = 0.0003
# 		 @10: HR = 0.0008, NDCG = 0.0003, Rec = 0.0008

# %%
cold_groups = []
for g in test_cold.keys():
    cold_groups.append(g)
cold_group_indicies = torch.LongTensor(cold_groups)

# %%
g_shape = agree.groupembeds.groupEmbedding.weight[cold_group_indicies].shape

# %%
for _ in range(3):
    with torch.no_grad():
        agree.groupembeds.groupEmbedding.weight[cold_group_indicies] = torch.randn(g_shape)
    print('cold')
    ret = evaluation(agree, test_cold, config.topK[:2], dataset.group_trainRatings, dataset.num_items)
    print('warm')
    ret = evaluation(agree, test_warm, config.topK[:2], dataset.group_trainRatings, dataset.num_items)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-11-829ab463cb37> in <module>
#       1 for _ in range(3):
#       2     with torch.no_grad():
# ----> 3         agree.groupembeds.groupEmbedding.weight[cold_group_indicies] = torch.randn(g_shape)
#       4     print('cold')
#       5     ret = evaluation(agree, test_cold, config.topK[:2], dataset.group_trainRatings, dataset.num_items)
#
# RuntimeError: Expected all tensors to be on the same device, but found at least two devices, cuda:0 and cpu!
