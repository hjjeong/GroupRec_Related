# %%
#Pytorch
import torch
import torch.nn as nn
import torch.autograd as autograd
from torch.autograd import Variable
import torch.optim as optim
import torch.nn.functional as F
#Python Libs
import numpy as np
from time import time
import datetime
#Implementations
from model.agree_re import VARGR_AGREE3
from config_CA import Config
from dataset_Meetup import GDataset
from batch_test import *

# %%
WU_point = 20
def training(model, train_loader, epoch_id, config):
    # user trainning
    t1 = time()
    model.train()
    learning_rates = config.lr
    lr = learning_rates[0] #if epoch_id<WU_point else 0.01
    beta = 0.0 if epoch_id<WU_point else 1.0
    beta2 = 0.0 if epoch_id<2*WU_point else 1.0
    # optimizer
    optimizer = optim.Adam(model.parameters(), lr=lr)

    losses = []

    *_, last = train_loader

    for batch_id, (g, pi_ni) in enumerate(train_loader):
        # Data Load
        group_input = g
        pos_item_input = pi_ni[:, 0]
        neg_item_input = pi_ni[:, 1]

        pos_prediction, pos_prediction2, dkl = model(group_input, pos_item_input, is_training=True)
        neg_prediction, neg_prediction2, _ = model(group_input, neg_item_input, is_training=True)

        # Zero_grad
        model.zero_grad()
        # Loss
        eps=1e-7
        loss = (1-beta2)*(torch.mean(-torch.log(pos_prediction+eps)-torch.log(1.0-neg_prediction+eps))+beta*(dkl))+beta2*(torch.mean(-torch.log(pos_prediction2+eps)-torch.log(1.0-neg_prediction2+eps)))
        
        # record loss history
        #print("batch_id: " + str(batch_id) + " loss: " + str(loss.item()))
        if not torch.isinf(loss.data) and not torch.isnan(loss.data):
            losses.append(float(loss.item()))
        # Backward
        loss.backward()
        optimizer.step()

    print('Iteration %d,\tloss: [%.4f], time: [%.1fs]' % (epoch_id, np.mean(np.array(losses)), time() - t1))

# %%
def evaluation(model, groups_to_test, Ks, trainRatings, num_items):
    model.eval()
    t2 = time()
    ret = test(model, groups_to_test, Ks, trainRatings, num_items) #See batch_test

    print('\t Evaluation done [%.1f s]' % (time() - t2))
    for i, k in enumerate(Ks):
        print('\t\t @%d: HR = %.4f, NDCG = %.4f, Rec = %.4f' % (k, ret['hit_ratio'][i], ret['ndcg'][i], ret['recall'][i]))
    return ret

# %%
config = Config()
# Out:
# meetup.ca 80 256

# %%
dataset = GDataset(config.user_dataset, config.group_dataset, config.user_in_group_path, 1)
num_groups, num_users, num_items = dataset.num_groups, dataset.num_users, dataset.num_items
print("num_groups: "+str(num_groups)+" num_users: "+str(num_users)+" num_items: "+str(num_items))
gu_dict = dataset.gu_dict
# Out:
# num_groups: 607 num_users: 56878 num_items: 1490

# %%
test_warm = dataset.load_rating_file_as_dict(config.group_dataset + ".test.rating_warm")
test_cold = dataset.load_rating_file_as_dict(config.group_dataset + ".test.rating_cold")
#ret = evaluation(agree, test_warm, config.topK[:2], dataset.group_trainRatings, dataset.num_items)
#ret = evaluation(agree, test_cold, config.topK[:2], dataset.group_trainRatings, dataset.num_items)

# %%
agree = VARGR_AGREE3(num_users, num_items, num_groups, config.embedding_size, gu_dict, config.drop_ratio).cuda()
best_checkpoint = -1.0
best_weights_path = None
for num_negatives in config.num_negatives:
    dataset.num_negatives = num_negatives
    print("AGREE: embedding size %d, run Iteration: %d, #neg: %d" %(config.embedding_size, config.epoch, num_negatives))
    # train the model
    now = datetime.datetime.now().strftime("%Y-%m-%d")

    for epoch in range(config.epoch): 
        training(agree, dataset.get_group_dataloader(config.batch_size), epoch, config)
        

        # Evaluation
        if epoch > WU_point:

            #ret = evaluation(agree, dataset.group_testRatings, config.topK[:2], dataset.group_trainRatings, dataset.num_items)
            ret = evaluation(agree, test_warm, config.topK[:2], dataset.group_trainRatings, dataset.num_items)
            cur_checkpoint = ret['ndcg'][1]
            #ret = evaluation(agree, test_cold, config.topK[:2], dataset.group_trainRatings, dataset.num_items)
            #cur_checkpoint += ret['hit_ratio'][1]
            #cur_checkpoint = cur_checkpoint/2
            current_weights_path = 'weights/VARGR_AGREE3_'+str(config.dataset)+"_"+str(config.embedding_size)+"_"+str(config.lr[0])+'_'+str(num_negatives)+'_'+str(epoch)
            torch.save(agree.state_dict(), current_weights_path)
            if best_checkpoint <= cur_checkpoint:
                best_weights_path = current_weights_path
                best_checkpoint = cur_checkpoint
# Out:
# AGREE: embedding size 32, run Iteration: 80, #neg: 4
# Iteration 0,	loss: [1.1653], time: [92.1s]
# Iteration 1,	loss: [0.8119], time: [91.1s]
# Iteration 2,	loss: [0.4782], time: [91.0s]
# Iteration 3,	loss: [0.3105], time: [91.7s]
# Iteration 4,	loss: [0.2197], time: [91.9s]
# Iteration 5,	loss: [0.1551], time: [100.9s]
# Iteration 6,	loss: [0.1325], time: [80.3s]
# Iteration 7,	loss: [0.1075], time: [64.2s]
# Iteration 8,	loss: [0.0923], time: [69.1s]
# Iteration 9,	loss: [0.0882], time: [69.8s]
# Iteration 10,	loss: [0.0822], time: [64.0s]
# Iteration 11,	loss: [0.0773], time: [65.3s]
# Iteration 12,	loss: [0.0774], time: [65.7s]
# Iteration 13,	loss: [0.0888], time: [64.8s]
# Iteration 14,	loss: [0.0878], time: [64.3s]
# Iteration 15,	loss: [0.0827], time: [65.2s]
# Iteration 16,	loss: [0.0872], time: [65.3s]
# Iteration 17,	loss: [0.0928], time: [65.4s]
# Iteration 18,	loss: [0.0878], time: [74.3s]
# Iteration 19,	loss: [0.0951], time: [82.8s]
# Iteration 20,	loss: [59.7758], time: [81.1s]
# Iteration 21,	loss: [29.2283], time: [64.9s]
# 	 Evaluation done [174.2 s]
# 		 @5: HR = 0.2923, NDCG = 0.1668, Rec = 0.1936
# 		 @10: HR = 0.4615, NDCG = 0.2375, Rec = 0.3295
# Iteration 22,	loss: [12.0272], time: [64.3s]
# 	 Evaluation done [172.1 s]
# 		 @5: HR = 0.3077, NDCG = 0.1804, Rec = 0.2000
# 		 @10: HR = 0.4538, NDCG = 0.2312, Rec = 0.2987
# Iteration 23,	loss: [6.8012], time: [64.6s]
# 	 Evaluation done [170.7 s]
# 		 @5: HR = 0.3385, NDCG = 0.1944, Rec = 0.2167
# 		 @10: HR = 0.4462, NDCG = 0.2417, Rec = 0.3051
# Iteration 24,	loss: [3.7572], time: [64.0s]
# 	 Evaluation done [179.3 s]
# 		 @5: HR = 0.3769, NDCG = 0.2263, Rec = 0.2526
# 		 @10: HR = 0.4769, NDCG = 0.2715, Rec = 0.3449
# Iteration 25,	loss: [2.8915], time: [66.0s]
# 	 Evaluation done [196.8 s]
# 		 @5: HR = 0.3615, NDCG = 0.2111, Rec = 0.2487
# 		 @10: HR = 0.5000, NDCG = 0.2661, Rec = 0.3526
# Iteration 26,	loss: [3.8749], time: [65.2s]
# 	 Evaluation done [178.9 s]
# 		 @5: HR = 0.3615, NDCG = 0.2106, Rec = 0.2474
# 		 @10: HR = 0.4846, NDCG = 0.2644, Rec = 0.3654
# Iteration 27,	loss: [1.9457], time: [65.1s]
# 	 Evaluation done [183.2 s]
# 		 @5: HR = 0.3077, NDCG = 0.1775, Rec = 0.1923
# 		 @10: HR = 0.4692, NDCG = 0.2456, Rec = 0.3333
# Iteration 28,	loss: [3.2507], time: [65.3s]
# 	 Evaluation done [177.8 s]
# 		 @5: HR = 0.3308, NDCG = 0.1979, Rec = 0.2167
# 		 @10: HR = 0.5000, NDCG = 0.2638, Rec = 0.3500
# Iteration 29,	loss: [1.5516], time: [65.6s]
# 	 Evaluation done [176.3 s]
# 		 @5: HR = 0.3462, NDCG = 0.1993, Rec = 0.2269
# 		 @10: HR = 0.4769, NDCG = 0.2556, Rec = 0.3462
# Iteration 30,	loss: [1.5026], time: [65.9s]
# 	 Evaluation done [177.9 s]
# 		 @5: HR = 0.3462, NDCG = 0.2180, Rec = 0.2244
# 		 @10: HR = 0.5077, NDCG = 0.2901, Rec = 0.3705
# Iteration 31,	loss: [2.5064], time: [65.0s]
# 	 Evaluation done [185.5 s]
# 		 @5: HR = 0.3462, NDCG = 0.2149, Rec = 0.2308
# 		 @10: HR = 0.5000, NDCG = 0.2814, Rec = 0.3731
# Iteration 32,	loss: [1.4132], time: [68.9s]
# 	 Evaluation done [179.4 s]
# 		 @5: HR = 0.3692, NDCG = 0.2006, Rec = 0.2372
# 		 @10: HR = 0.4692, NDCG = 0.2551, Rec = 0.3513
# Iteration 33,	loss: [1.7178], time: [68.2s]
# 	 Evaluation done [180.4 s]
# 		 @5: HR = 0.3538, NDCG = 0.1939, Rec = 0.2269
# 		 @10: HR = 0.4692, NDCG = 0.2547, Rec = 0.3628
# Iteration 34,	loss: [1.4639], time: [75.4s]
# 	 Evaluation done [195.5 s]
# 		 @5: HR = 0.3538, NDCG = 0.2126, Rec = 0.2154
# 		 @10: HR = 0.5231, NDCG = 0.2849, Rec = 0.3692
# Iteration 35,	loss: [1.0107], time: [74.7s]
# 	 Evaluation done [219.9 s]
# 		 @5: HR = 0.3692, NDCG = 0.2157, Rec = 0.2474
# 		 @10: HR = 0.5077, NDCG = 0.2784, Rec = 0.3821
# Iteration 36,	loss: [0.8994], time: [83.6s]
# 	 Evaluation done [180.0 s]
# 		 @5: HR = 0.3615, NDCG = 0.2036, Rec = 0.2436
# 		 @10: HR = 0.4846, NDCG = 0.2660, Rec = 0.3564
# Iteration 37,	loss: [1.1163], time: [67.3s]
# 	 Evaluation done [178.9 s]
# 		 @5: HR = 0.3308, NDCG = 0.2001, Rec = 0.2295
# 		 @10: HR = 0.5077, NDCG = 0.2684, Rec = 0.3628
# Iteration 38,	loss: [1.0566], time: [66.0s]
# 	 Evaluation done [178.0 s]
# 		 @5: HR = 0.3692, NDCG = 0.2440, Rec = 0.2385
# 		 @10: HR = 0.4846, NDCG = 0.2939, Rec = 0.3564
# Iteration 39,	loss: [1.5164], time: [67.8s]
# 	 Evaluation done [178.1 s]
# 		 @5: HR = 0.3538, NDCG = 0.2200, Rec = 0.2410
# 		 @10: HR = 0.5077, NDCG = 0.2834, Rec = 0.3769
# Iteration 40,	loss: [0.0939], time: [68.0s]
# 	 Evaluation done [179.0 s]
# 		 @5: HR = 0.3615, NDCG = 0.2120, Rec = 0.2641
# 		 @10: HR = 0.5077, NDCG = 0.2714, Rec = 0.3782
# Iteration 41,	loss: [0.0999], time: [67.7s]
# 	 Evaluation done [178.2 s]
# 		 @5: HR = 0.3077, NDCG = 0.1991, Rec = 0.2103
# 		 @10: HR = 0.5308, NDCG = 0.2866, Rec = 0.4038
# Iteration 42,	loss: [0.1064], time: [67.5s]
# 	 Evaluation done [178.1 s]
# 		 @5: HR = 0.3769, NDCG = 0.2265, Rec = 0.2692
# 		 @10: HR = 0.5385, NDCG = 0.3006, Rec = 0.4077
# Iteration 43,	loss: [0.0987], time: [67.7s]
# 	 Evaluation done [180.0 s]
# 		 @5: HR = 0.3846, NDCG = 0.2472, Rec = 0.2731
# 		 @10: HR = 0.5538, NDCG = 0.3190, Rec = 0.4256
# Iteration 44,	loss: [0.1061], time: [68.1s]
# 	 Evaluation done [178.7 s]
# 		 @5: HR = 0.3923, NDCG = 0.2580, Rec = 0.2731
# 		 @10: HR = 0.5000, NDCG = 0.3099, Rec = 0.3808
# Iteration 45,	loss: [0.0904], time: [67.6s]
# 	 Evaluation done [178.7 s]
# 		 @5: HR = 0.3231, NDCG = 0.2294, Rec = 0.2256
# 		 @10: HR = 0.5154, NDCG = 0.3021, Rec = 0.3692
# Iteration 46,	loss: [0.0880], time: [67.1s]
# 	 Evaluation done [177.5 s]
# 		 @5: HR = 0.3308, NDCG = 0.2139, Rec = 0.2346
# 		 @10: HR = 0.5000, NDCG = 0.2851, Rec = 0.3833
# Iteration 47,	loss: [0.1002], time: [67.4s]
# 	 Evaluation done [177.8 s]
# 		 @5: HR = 0.3154, NDCG = 0.2158, Rec = 0.2154
# 		 @10: HR = 0.5231, NDCG = 0.2974, Rec = 0.3923
# Iteration 48,	loss: [0.1113], time: [67.4s]
# 	 Evaluation done [178.9 s]
# 		 @5: HR = 0.3769, NDCG = 0.2357, Rec = 0.2538
# 		 @10: HR = 0.5231, NDCG = 0.2962, Rec = 0.3731
# Iteration 49,	loss: [0.0934], time: [67.5s]
# 	 Evaluation done [178.3 s]
# 		 @5: HR = 0.3538, NDCG = 0.2285, Rec = 0.2474
# 		 @10: HR = 0.5154, NDCG = 0.2966, Rec = 0.3859
# Iteration 50,	loss: [0.1113], time: [67.5s]
# 	 Evaluation done [178.9 s]
# 		 @5: HR = 0.3308, NDCG = 0.2028, Rec = 0.2231
# 		 @10: HR = 0.4923, NDCG = 0.2682, Rec = 0.3538
# Iteration 51,	loss: [0.0889], time: [67.9s]
# 	 Evaluation done [181.4 s]
# 		 @5: HR = 0.3538, NDCG = 0.2309, Rec = 0.2436
# 		 @10: HR = 0.5538, NDCG = 0.3081, Rec = 0.4077
# Iteration 52,	loss: [0.0936], time: [67.8s]
# 	 Evaluation done [178.9 s]
# 		 @5: HR = 0.3462, NDCG = 0.2269, Rec = 0.2397
# 		 @10: HR = 0.5462, NDCG = 0.3088, Rec = 0.4051
# Iteration 53,	loss: [0.0977], time: [67.7s]
# 	 Evaluation done [178.6 s]
# 		 @5: HR = 0.3231, NDCG = 0.2077, Rec = 0.2103
# 		 @10: HR = 0.5077, NDCG = 0.2827, Rec = 0.3731
# Iteration 54,	loss: [0.0960], time: [67.2s]
# 	 Evaluation done [178.3 s]
# 		 @5: HR = 0.3615, NDCG = 0.2207, Rec = 0.2500
# 		 @10: HR = 0.5231, NDCG = 0.2825, Rec = 0.3833
# Iteration 55,	loss: [0.0928], time: [67.7s]
# 	 Evaluation done [178.3 s]
# 		 @5: HR = 0.3538, NDCG = 0.2180, Rec = 0.2346
# 		 @10: HR = 0.5000, NDCG = 0.2777, Rec = 0.3667
# Iteration 56,	loss: [0.0892], time: [67.5s]
# 	 Evaluation done [179.0 s]
# 		 @5: HR = 0.3615, NDCG = 0.2177, Rec = 0.2474
# 		 @10: HR = 0.5077, NDCG = 0.2791, Rec = 0.3731
# Iteration 57,	loss: [0.0883], time: [66.4s]
# 	 Evaluation done [179.1 s]
# 		 @5: HR = 0.3231, NDCG = 0.2222, Rec = 0.2346
# 		 @10: HR = 0.4846, NDCG = 0.2836, Rec = 0.3603
# Iteration 58,	loss: [0.0857], time: [67.0s]
# 	 Evaluation done [178.6 s]
# 		 @5: HR = 0.3769, NDCG = 0.2422, Rec = 0.2538
# 		 @10: HR = 0.4692, NDCG = 0.2839, Rec = 0.3462
# Iteration 59,	loss: [0.0922], time: [67.4s]
# 	 Evaluation done [178.4 s]
# 		 @5: HR = 0.3462, NDCG = 0.2446, Rec = 0.2436
# 		 @10: HR = 0.5231, NDCG = 0.3096, Rec = 0.3808
# Iteration 60,	loss: [0.0945], time: [66.6s]
# 	 Evaluation done [178.3 s]
# 		 @5: HR = 0.3615, NDCG = 0.2180, Rec = 0.2538
# 		 @10: HR = 0.5077, NDCG = 0.2793, Rec = 0.3885
# Iteration 61,	loss: [0.0977], time: [67.1s]
# 	 Evaluation done [179.3 s]
# 		 @5: HR = 0.3615, NDCG = 0.2285, Rec = 0.2500
# 		 @10: HR = 0.5231, NDCG = 0.2929, Rec = 0.3808
# Iteration 62,	loss: [0.0966], time: [66.3s]
# 	 Evaluation done [179.8 s]
# 		 @5: HR = 0.3308, NDCG = 0.2211, Rec = 0.2154
# 		 @10: HR = 0.5000, NDCG = 0.2858, Rec = 0.3679
# Iteration 63,	loss: [0.0958], time: [66.9s]
# 	 Evaluation done [178.3 s]
# 		 @5: HR = 0.3385, NDCG = 0.2051, Rec = 0.2282
# 		 @10: HR = 0.5154, NDCG = 0.2740, Rec = 0.3603
# Iteration 64,	loss: [0.0852], time: [66.9s]
# 	 Evaluation done [179.1 s]
# 		 @5: HR = 0.3231, NDCG = 0.2050, Rec = 0.2179
# 		 @10: HR = 0.5000, NDCG = 0.2773, Rec = 0.3654
# Iteration 65,	loss: [0.0856], time: [66.9s]
# 	 Evaluation done [178.8 s]
# 		 @5: HR = 0.3615, NDCG = 0.2092, Rec = 0.2474
# 		 @10: HR = 0.5000, NDCG = 0.2685, Rec = 0.3667
# Iteration 66,	loss: [0.0995], time: [67.5s]
# 	 Evaluation done [178.9 s]
# 		 @5: HR = 0.3462, NDCG = 0.2293, Rec = 0.2397
# 		 @10: HR = 0.4846, NDCG = 0.2800, Rec = 0.3436
# Iteration 67,	loss: [0.0889], time: [67.0s]
# 	 Evaluation done [178.8 s]
# 		 @5: HR = 0.3846, NDCG = 0.2376, Rec = 0.2538
# 		 @10: HR = 0.5077, NDCG = 0.2939, Rec = 0.3603
# Iteration 68,	loss: [0.0973], time: [67.4s]
# 	 Evaluation done [179.0 s]
# 		 @5: HR = 0.3692, NDCG = 0.2362, Rec = 0.2462
# 		 @10: HR = 0.4923, NDCG = 0.2866, Rec = 0.3590
# Iteration 69,	loss: [0.0962], time: [66.8s]
# 	 Evaluation done [179.6 s]
# 		 @5: HR = 0.4077, NDCG = 0.2555, Rec = 0.2641
# 		 @10: HR = 0.4846, NDCG = 0.2935, Rec = 0.3410
# Iteration 70,	loss: [0.0875], time: [67.2s]
# 	 Evaluation done [179.0 s]
# 		 @5: HR = 0.3462, NDCG = 0.2230, Rec = 0.2449
# 		 @10: HR = 0.5077, NDCG = 0.2844, Rec = 0.3731
# Iteration 71,	loss: [0.0728], time: [67.1s]
# 	 Evaluation done [179.1 s]
# 		 @5: HR = 0.3846, NDCG = 0.2482, Rec = 0.2513
# 		 @10: HR = 0.5154, NDCG = 0.3053, Rec = 0.3795
# Iteration 72,	loss: [0.0885], time: [67.8s]
# 	 Evaluation done [178.6 s]
# 		 @5: HR = 0.4154, NDCG = 0.2487, Rec = 0.2795
# 		 @10: HR = 0.5000, NDCG = 0.2917, Rec = 0.3679
# Iteration 73,	loss: [0.0922], time: [67.1s]
# 	 Evaluation done [178.9 s]
# 		 @5: HR = 0.3923, NDCG = 0.2382, Rec = 0.2526
# 		 @10: HR = 0.5000, NDCG = 0.2909, Rec = 0.3654
# Iteration 74,	loss: [0.0917], time: [67.2s]
# 	 Evaluation done [178.4 s]
# 		 @5: HR = 0.3231, NDCG = 0.1972, Rec = 0.2128
# 		 @10: HR = 0.4769, NDCG = 0.2625, Rec = 0.3462
# Iteration 75,	loss: [0.0999], time: [66.9s]
# 	 Evaluation done [178.5 s]
# 		 @5: HR = 0.3385, NDCG = 0.2124, Rec = 0.2090
# 		 @10: HR = 0.4846, NDCG = 0.2728, Rec = 0.3397
# Iteration 76,	loss: [0.0872], time: [67.4s]
# 	 Evaluation done [178.6 s]
# 		 @5: HR = 0.2846, NDCG = 0.1872, Rec = 0.1910
# 		 @10: HR = 0.4923, NDCG = 0.2715, Rec = 0.3628
# Iteration 77,	loss: [0.0860], time: [67.2s]
# 	 Evaluation done [178.9 s]
# 		 @5: HR = 0.3154, NDCG = 0.2005, Rec = 0.2103
# 		 @10: HR = 0.4923, NDCG = 0.2671, Rec = 0.3423
# Iteration 78,	loss: [0.0985], time: [67.0s]
# 	 Evaluation done [179.0 s]
# 		 @5: HR = 0.3538, NDCG = 0.2151, Rec = 0.2346
# 		 @10: HR = 0.5231, NDCG = 0.2862, Rec = 0.3718
# Iteration 79,	loss: [0.1099], time: [67.2s]
# 	 Evaluation done [178.4 s]
# 		 @5: HR = 0.3615, NDCG = 0.2328, Rec = 0.2397
# 		 @10: HR = 0.5231, NDCG = 0.3014, Rec = 0.3846

# %%
agree = VARGR_AGREE3(num_users, num_items, num_groups, config.embedding_size, gu_dict, config.drop_ratio).cuda()
agree.load_state_dict(torch.load(best_weights_path))
print(best_weights_path)
# Out:
# weights/VARGR_AGREE3_meetup.ca_32_0.01_4_43

# %%
print('total')
ret = evaluation(agree, dataset.group_testRatings, config.topK[:2], dataset.group_trainRatings, dataset.num_items)
print('cold')
ret = evaluation(agree, test_cold, config.topK[:2], dataset.group_trainRatings, dataset.num_items)
print('warm')
ret = evaluation(agree, test_warm, config.topK[:2], dataset.group_trainRatings, dataset.num_items)
# Out:
# total
# 	 Evaluation done [238.1 s]
# 		 @5: HR = 0.3333, NDCG = 0.1952, Rec = 0.2131
# 		 @10: HR = 0.5115, NDCG = 0.2700, Rec = 0.3669
# cold
# 	 Evaluation done [59.9 s]
# 		 @5: HR = 0.2273, NDCG = 0.1394, Rec = 0.0985
# 		 @10: HR = 0.3864, NDCG = 0.1932, Rec = 0.1913
# warm
# 	 Evaluation done [179.5 s]
# 		 @5: HR = 0.4154, NDCG = 0.2390, Rec = 0.2885
# 		 @10: HR = 0.5538, NDCG = 0.3057, Rec = 0.4282
